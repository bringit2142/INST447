# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = "Caleb Andree"
COLLABORATORS = ""

# %% [markdown]
# ---

# %% [markdown]
# <div class="alert alert-warning"><b>⚠️ Do not validate this notebook! ⚠️</b> Before you submit do <i>Kernel &rarr; Restart &amp; Run All</i> and manually inspect all code cells. The validate button (both here and in the <tt>Assignments</tt> tab) does not work on this notebook. (It will lie to you: it will say that all tests passed but there are no autograded tests!)</div>
#
# # Programming Assignment 4: Thanksgiving dinner analysis [Total: 14 pts]
#
# ## Table of Contents
# <ul>
#     <li><a href="#Description">Description</a></li>
#     <li><a href="#Research-questions">Research questions</a></li>
#     <li><a href="#Required-skills">Required skills</a></li>
#     <li><a href="#What-to-submit">What to submit</a></li>
#     <li><a href="#Grading-rubric">Grading rubric</a></li>
#     <li><a href="#Instructions-to-get-the-API-key">Instructions to get the API key</a></li>
#     <li><a href="#Submission-checklist">Submission checklist</a> [1 point]</li>
#     <li><a href="#Q1">Question 1</a> [1 points]</li>
#     <li><a href="#Viz2">Question 2 (Viz 2)</a> [4 points]</li>
#     <li><a href="#Viz3">Question 3 (Viz 3)</a> [4 points]</li>
#     <li><a href="#Viz4">Question 4 (Viz 4)</a> [4 points]</li>
# </ul>

# %% [markdown]
# ## Description
#
# In this assignment, you will use the Food Data Central API to pull the nutritional content of a typical Thanksgiving Meal.
# Follow the instructions and answer the research questions given.
#
#
# ## Research questions
#
# 1) Create the dataframe by following the instructions and then use this dataframe to answer the research questions.
#
# 2) Is there an association between the amount of protein and energy in a food?
#
# 3) Which of the Thanksgiving foods would you say is the healthiest/most nutritious, and why?
#
# 4) Is there an association between the amount of protein and carbs in a food?
#
#
# ## Required Skills
#
# This lab will let you practice the following skills:
# - Sending request to a server using python requests module.
# - Interpreting the response of the request.
# - Analyzing bar graphs and plots, getting insights from the graphs.
#
# A few additional resources can be found here:
# - https://docs.python-requests.org/
#
#
# ## Grading rubric
#
# * The submission checklist is worth **1 points**, see [the checklist cell](#Submission-checklist) for more information.
# * Each visualization is worth **4 points**, with these possible penalties:
#   - Up to &minus;1 pt penalty missing / uninformative axis label (note this applies to each axis separately, so this is max &minus;2 pts).
#   - Up to &minus;1 pt penalty for missing / uninformative title.
#   - Up to &minus;1 pt penalty for missing / too short / uninformative plot description.
# * The final summary is worth **3 points**, with these possible penalties:
#   - Up to &minus;1 pt penalty for not meeting the minimum length (&ge;150 words);
#   - Up to &minus;1 pt penalty for not summarizing findings of _all two_ plots;
#
#
# ## Instructions to get the API key
#
# <div class="alert alert-warning">⚠️ For any issue with registering your API key, please contact the <a src="https://fdc.nal.usda.gov/contact.html">Food Data Central team</a>. We are unable to assist with API registration issues. ⚠️</div>
#
# To work on this notebook you need to register an API key. Please follow these instructions to do so:
# 1. Go to https://fdc.nal.usda.gov/api-key-signup.html;
# 2. Enter your first name, last name, and UMD email address;
# 3. Click on the sign up button;
# 4. Wait for the email with the API key. You should receive a confirmation email in a few minutes.
#
# You should familiarize with the [API developer manual](https://api.data.gov/docs/developer-manual/) that explains how to use the newly created API key in your code.

# %% [markdown]
# ## Submission checklist
#
# **Points**: 1
#
# Before submitting make sure that:
#
# 1. Your name is included above, plus the name of any collaborator you worked with;
# 2. All Markdown cells you edited are rendering correctly, especially the ones with answers.
# 3. You have removed any `raise NotImplementedError()` line from your code cells.
# 4. ⚡**NEW**⚡ You have included your API key in the notebook so we can re-run your code. (See instructions below.)

# %% [markdown]
# ## Q1
#
# **Points:** 1
#
# The FoodCentral database contains nutrient information (e.g. amount dietary fibers) of various food products (e.g. pizza, pasta, etc.). Write a function called `food_nutrients` that uses the `GET /v1/foods/search` endpoint [[API docs](https://fdc.nal.usda.gov/api-guide.html#bkmk-6)] to summarize the nutrient information of the most common types of foods.
#
# Use your Food Data Central API Key to send an API request to search the database for the following list of Thanksgiving dinner foods:
# - turkey
# - macaroni and cheese
# - mashed potatoes
# - bread stuffing
# - ham
# - sweet potato souffle
# - cranberry sauce
# - mixed vegetables
# - apple pie
# - pecan pie.
#
# Create a dataframe with the average nutrient values for energy, carbs, protein, fiber, and fat for the foods in the list above.
#
# In addition, your function should filter the results to keep only the most common nutrients, and abbreviate the name of the nutrients to simplify the rest of the analysis. The following table lists the nutrients to include in the data frame, and how they should be renamed after cleaning.
#
# | Nutrient name from API | Cleaned nutrient name |
# | --------- | --------- |
# | `Energy`  | `Energy`  |
# | `Carbohydrate, by difference` | `Carbs` |
# | `Protein` | `Protein` |
# | `Fiber, total dietary` | `Fiber` |
# | `Total lipid (fat)` | `Fat` |
#
# Using the above foods, the resulting dataframe should be:
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energy</th>
#       <th>Carbs</th>
#       <th>Protein</th>
#       <th>Fiber</th>
#       <th>Fat</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>apple pie</th>
#       <td>349.185185</td>
#       <td>37.612000</td>
#       <td>3.437800</td>
#       <td>2.516327</td>
#       <td>14.150200</td>
#     </tr>
#     <tr>
#       <th>bread stuffing</th>
#       <td>323.490566</td>
#       <td>35.445918</td>
#       <td>7.967708</td>
#       <td>1.910417</td>
#       <td>8.429796</td>
#     </tr>
#     <tr>
#       <th>cranberry sauce</th>
#       <td>185.326923</td>
#       <td>39.026531</td>
#       <td>0.073469</td>
#       <td>1.491667</td>
#       <td>0.424792</td>
#     </tr>
#     <tr>
#       <th>ham</th>
#       <td>286.131148</td>
#       <td>8.710600</td>
#       <td>13.822400</td>
#       <td>0.590698</td>
#       <td>8.641400</td>
#     </tr>
#     <tr>
#       <th>macaroni and cheese</th>
#       <td>335.470588</td>
#       <td>21.179000</td>
#       <td>6.807000</td>
#       <td>0.978000</td>
#       <td>7.365600</td>
#     </tr>
#     <tr>
#       <th>mashed potatoes</th>
#       <td>252.461538</td>
#       <td>45.777551</td>
#       <td>4.943469</td>
#       <td>3.434694</td>
#       <td>4.096735</td>
#     </tr>
#     <tr>
#       <th>mixed vegetables</th>
#       <td>47.380000</td>
#       <td>9.386458</td>
#       <td>1.587755</td>
#       <td>2.112245</td>
#       <td>0.010833</td>
#     </tr>
#     <tr>
#       <th>pecan pie</th>
#       <td>460.365385</td>
#       <td>50.666000</td>
#       <td>4.320400</td>
#       <td>2.026531</td>
#       <td>21.850000</td>
#     </tr>
#     <tr>
#       <th>sweet potato souffle</th>
#       <td>215.666667</td>
#       <td>37.533333</td>
#       <td>2.433333</td>
#       <td>1.533333</td>
#       <td>6.258333</td>
#     </tr>
#     <tr>
#       <th>turkey</th>
#       <td>393.138462</td>
#       <td>7.726800</td>
#       <td>16.309400</td>
#       <td>0.457447</td>
#       <td>11.490800</td>
#     </tr>
#   </tbody>
# </table>
#
#
# ### Hints:
# - You may find it helpful to organize your code using multiple functions.
# - This question builds on Lab 10, so make sure to have completed that before attempting this question.
# - Since many Thanksgiving foods have multiple terms, make sure to set `requireAllWords` to True in your API calls.
#
# ### Q1: Code cell
#
# Use the code cell below to produce your dataframe.

# %%
import pandas as pd
import requests
URL = "https://api.nal.usda.gov/fdc/v1/foods/search"
api_key = 'Ne89cpPQu8jJX369N7p3DT7UTZ1FcxcmFf0pBn89'
# YOUR CODE HERE

def food_nutrients(query):
    params = {"api_key": api_key, "query": query, "requireAllWords": "true"}

    response = requests.get(URL, params=params)

    if response.status_code == 200:
        data = response.json()
        if data and 'foods' in data and data['foods']:
            nutrient_list = []
            for food in data['foods']:
                if 'foodNutrients' in food:
                    nutrient_list.extend(food['foodNutrients'])

            df = pd.DataFrame(nutrient_list)

            nutrient_mapping = {
                'Energy': 'Energy',
                'Carbohydrate, by difference': 'Carbs',
                'Protein': 'Protein',
                'Fiber, total dietary': 'Fiber',
                'Total lipid (fat)': 'Fat'
            }

            df = df[df['nutrientName'].isin(nutrient_mapping.keys())]
            df['nutrientName'] = df['nutrientName'].map(nutrient_mapping)

            result_df = df.groupby('nutrientName').agg({'value': 'mean', 'unitName': 'first'}).reset_index()

            return result_df
        
        
def menu_nutrients(menu):
    nutrients_list = []

    for food in menu:
        nutrients = food_nutrients(food)

        if nutrients is not None:
            nutrients['food'] = food
            nutrients_list.append(nutrients)

    result_df = pd.concat(nutrients_list, ignore_index=True)

    result_df = result_df.pivot(index='food', columns='nutrientName', values='value').reset_index()

    result_df = result_df.fillna(0)
    result_df = result_df.set_index('food')
    result_df.index.name = None
    result_df.columns.name = None




    result_df = result_df[['Energy', 'Carbs', 'Protein', 'Fiber', 'Fat']]

    return result_df


#raise NotImplementedError()

# %% [markdown]
# Use the cell below to run your code with the required inputs.

# %%
required_foods = [
    "turkey", 
    "macaroni and cheese", 
    "mashed potatoes", 
    "bread stuffing", 
    "ham", 
    "sweet potato souffle", 
    "cranberry sauce", 
    "mixed vegetables", 
    "apple pie", 
    "pecan pie"
]

menu_nutrients(required_foods)
# Out:
#                           Energy      Carbs    Protein     Fiber        Fat
# apple pie             349.185185  37.612000   3.437800  2.516327  14.150200
# bread stuffing        323.490566  35.445918   7.967708  1.910417   8.429796
# cranberry sauce       185.326923  39.026531   0.073469  1.491667   0.424792
# ham                   286.131148   8.710600  13.822400  0.590698   8.641400
# macaroni and cheese   335.470588  21.179000   6.807000  0.978000   7.365600
# mashed potatoes       252.461538  45.777551   4.943469  3.434694   4.096735
# mixed vegetables       47.380000   9.386458   1.587755  2.112245   0.010833
# pecan pie             460.365385  50.666000   4.320400  2.026531  21.850000
# sweet potato souffle  215.666667  37.533333   2.433333  1.533333   6.258333
# turkey                393.138462   7.726800  16.309400  0.457447  11.490800

# %% [markdown]
# Once done, run the cell below to test your code in the autograder:

# %%
import pandas as pd
from pandas.testing import assert_frame_equal

def _q1autograder(menu):
    fname = f'.solution1-nutrients.csv'
    STUDENT_ANSWER = menu_nutrients(menu)
    CORRECT_ANSWER = pd.read_csv(fname, index_col=0)

    # Return value should match solution
    try:
        print(f"Testing that menu_nutrients({menu}) returns correct data frame".ljust(96, "."), end="")
        assert_frame_equal(STUDENT_ANSWER, CORRECT_ANSWER, check_names=False)
        print("PASSED.")
    except AssertionError:
        print("FAILED!")
        print()
        print("Error: your solution does not match the correct one. See below for mismatching entries.")
        print()
        idx = (STUDENT_ANSWER != CORRECT_ANSWER).any(axis=1)
        print("Mismatching entries")
        print("===================")
        print()
        print("Correct: ")
        print(CORRECT_ANSWER[idx])
        print()
        print("Student:")
        print(STUDENT_ANSWER[idx])

_q2CASES = ["turkey", "macaroni and cheese", "mashed potatoes", "bread stuffing", "ham", "sweet potato souffle", "cranberry sauce", 
"mixed vegetables", "apple pie", "pecan pie"]
        
_q1autograder(_q2CASES)

#if no test failed, print
print("\nAll tests passed! 👍")
# Out:
# Testing that menu_nutrients(['turkey', 'macaroni and cheese', 'mashed potatoes', 'bread stuffing', 'ham', 'sweet potato souffle', 'cranberry sauce', 'mixed vegetables', 'apple pie', 'pecan pie']) returns correct data framePASSED.
#
# All tests passed! 👍

# %% [markdown]
# ## Viz2
#
# **Total points:** 4
#
# **Research Question 2**: Is there an association between the amount of protein and energy in a food?
#
# ### Hint
#
# Create a plot to show this relationship (your plot must include a title &amp; proper axis labels).
#
#
# ### Viz2: Code cell
#
# **Points:** 3
#
# Use the code cell below to produce your plot. Refer to the [grading rubric](#Grading-rubric) for what to include in it. You may add extra cells if you like but please do not delete / duplicate that cell. Running your cell should display a plot.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

required_foods = [
    "turkey", 
    "macaroni and cheese", 
    "mashed potatoes", 
    "bread stuffing", 
    "ham", 
    "sweet potato souffle", 
    "cranberry sauce", 
    "mixed vegetables", 
    "apple pie", 
    "pecan pie"
]

scatter_df = menu_nutrients(required_foods)

plt.figure(figsize=(10, 6))
plt.scatter(scatter_df['Protein'], scatter_df['Energy'], alpha=0.8)

for i, food in enumerate(required_foods):
    plt.annotate(food, (scatter_df['Protein'][i], scatter_df['Energy'][i]), textcoords="offset points", xytext=(5,5), ha='right')
plt.title('Association between Protein and Energy in Thanksgiving Foods')
plt.xlabel('Protein (g)')
plt.ylabel('Energy (kcal)')
plt.grid(True)
plt.show()

#raise NotImplementedError()

# %% [markdown]
# ### Viz2: MarkDown cell
#
# **Points**: 1
#
# Use the markdown cell below to describe your plot and answer the research question findings. Refer to the [grading rubric](#Grading-rubric) for what to include in it.

# %% [markdown]
# This scatter plot highlights the amount of energy and protein in each type of Thanksgiving food. For some foods, there is an association between the 2, but for most of the foods, there is very little protein and a decent amount of energy. The only outliers would be bread stuffing and pecan pie, as they both have high protein and high energy.

# %% [markdown]
# ## Viz3
#
# **Research Question 3**: Create one plot divided into multiple subplots, where each subplot is a bar graph (for one nutrient each) to show the nutrient concentration of each food item across that nutrient. Each bar graph should show the concentration of a single nutrient across all food items in the thanksgiving dinner menu. All your subplots must include a title &amp; proper axis labels.
#
# ### Hint
#
# To produce a plot with multiple subplots, you can use the `plt.subplots` function (see [documentation here](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html#matplotlib.pyplot.subplots)).
#
# ### Viz3: Code cell
#
# **Points:** 3
#
# Use the code cell below to produce your plot. Refer to the [grading rubric](#Grading-rubric) for what to include in it. You may add extra cells if you like but please do not delete / duplicate that cell. Running your cell should display a plot.

# %%
## Multiple Bar Graphs 

# %matplotlib inline

# YOUR CODE HERE
required_foods = [
    'turkey',
    'macaroni and cheese',
    'mashed potatoes',
    'bread stuffing',
    'ham',
    'sweet potato souffle',
    'cranberry sauce',
    'mixed vegetables',
    'apple pie',
    'pecan pie'
]

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(20, 6))
fig.suptitle('Nutrient Concentration in Thanksgiving Foods', fontsize=16)
nutrients_list = ['Energy', 'Carbs', 'Protein', 'Fiber', 'Fat']

bar_df = menu_nutrients(required_foods)


for i, nutrient in enumerate(nutrients_list):
    ax = axes[i] 

    ax.bar(bar_df.index, bar_df[nutrient])
    ax.set_title(nutrient)
    ax.set_xlabel('Food Item')
    ax.set_ylabel(f'{nutrient} Content')

    ax.set_xticklabels(bar_df.index, rotation=45, ha='right')

plt.tight_layout(rect=[0, 0, 1, 0.96])

plt.show()
#raise NotImplementedError()
# Out:
# /tmp/ipykernel_2873719/2758298224.py:34: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(bar_df.index, rotation=45, ha='right')

# %% [markdown]
# ### Viz3: MarkDown cell
#
# **Points**: 1
#
# Use the markdown cell below to describe your plot and answer the research question findings. Refer to the [grading rubric](#Grading-rubric) for what to include in it.
#
# Based on the graphs above, answer the following research questions -
#
# <b>Which of the Thanksgiving foods would you say is the healthiest/most nutritious, and why? There is no one correct answer here.</b>

# %% [markdown]
# I think that the mac and cheese is the healthiest/most nutritious because overall, it is a very well-rounded food in terms of nutrients. It has a good amount of energy, balanced carbs, a decent amount of protain and fiber, and it is low in fat as well. It is a good food to eat if you want something that is well-balanced with the rest of your Thanksgiving meal.

# %% [markdown]
# ## Viz4
#
# **Total points**: 4
#
# **Research Question 4**: Is there an association between the amount of protein and carbs in a food?
#
# Hint: Create a plot to show this relationship (your plot must include a title & proper axis labels).
#
# ### Viz4: Code cell
#
# **Points:** 3
#
# Use the code cell below to produce your plot. Refer to the [grading rubric](#Grading-rubric) for what to include in it. You may add extra cells if you like but please do not delete / duplicate that cell. Running your cell should display a plot.

# %%
# %matplotlib inline

# YOUR CODE HERE
required_foods = [
    "turkey", 
    "macaroni and cheese", 
    "mashed potatoes", 
    "bread stuffing", 
    "ham", 
    "sweet potato souffle", 
    "cranberry sauce", 
    "mixed vegetables", 
    "apple pie", 
    "pecan pie"
]

scatter_df = menu_nutrients(required_foods)

plt.figure(figsize=(10, 6))
plt.scatter(scatter_df['Protein'], scatter_df['Carbs'], alpha=0.8)

for i, food in enumerate(required_foods):
    plt.annotate(food, (scatter_df['Protein'][i], scatter_df['Carbs'][i]), textcoords="offset points", xytext=(5,5), ha='right')
plt.title('Association between Protein and Energy in Thanksgiving Foods')
plt.xlabel('Protein (g)')
plt.ylabel('Carbs')
plt.grid(True)
plt.show()
#raise NotImplementedError()

# %% [markdown]
# ### Viz4: MarkDown cell
#
# **Points**: 1
#
# Use the markdown cell below to describe your plot and answer the research question findings. Refer to the [grading rubric](#Grading-rubric) for what to include in it.

# %% [markdown]
# According to this scatterplot, it appears that the higher a food is in protein, the lower the carbs are with that food. With the turkey, mixed vegetables, and sweet potato souffle, they are very high in carbs, but low in protein. With the bread stuffing and pecan pie, they have high protein, but very low carbs. This chart would be useful for people that want to eat more protein, but keep their carbs intake relatively low or vice versa.
